# %% [markdown]
# # Homework 2
# made by German Ilya

# %% [markdown]
# ## 1.

# %% [markdown]
# Chose gene and add it to https://docs.google.com/spreadsheets/d/1a4EPqfJqUfNl1E2iZy1tRvHzw1NX43LeMtP74i15ugo/edit?usp=sharing.
#
# You can find .fasta file with 14 different species [here](https://github.com/ilyagerman52/bioinformatics/blob/main/homework2/14_species(downloaded%20from%20ncbi).fasta).

# %% [markdown]
# ##2.

# %% [markdown]
# Make multiple alignment by clustalW and Muscle using [MEGA](https://www.megasoftware.net/).
#
# You can find file after ClustalW [here](https://github.com/ilyagerman52/bioinformatics/blob/main/homework2/after_clustalW_aligment.fas) and after Muscle [here](https://github.com/ilyagerman52/bioinformatics/blob/main/homework2/after_muscle_aligment.fas).
#
# The difference is obvious. For example we can find it on these screenshots:
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# (beginings of sequences)

# %% [markdown]
# ##3.

# %% [markdown]
# Construct phylogenetic tree by different methods.
# You can find all combinations [here](https://github.com/ilyagerman52/bioinformatics/tree/main/homework2/trees).
#
# After ClustalW alignment:
#
# $\;\;\;\;\;\;$ [UPGMA](https://github.com/ilyagerman52/bioinformatics/blob/main/homework2/trees/UPGMA_tree_cW_orig.pdf)
#
# $\;\;\;\;\;\;$ [NJ](https://github.com/ilyagerman52/bioinformatics/blob/main/homework2/trees/NJ_tree_cW_orig.pdf)
#
# $\;\;\;\;\;\;$ [maximal likelihood](https://github.com/ilyagerman52/bioinformatics/blob/main/homework2/trees/maxlikelihood_tree_cW_orig.pdf)
#
# After Muscle alignment:
#
# $\;\;\;\;\;\;$ [UPGMA](https://github.com/ilyagerman52/bioinformatics/blob/main/homework2/trees/UPGMA_tree_m_orig.pdf)
#
# $\;\;\;\;\;\;$ [NJ](https://github.com/ilyagerman52/bioinformatics/blob/main/homework2/trees/NJ_tree_m_orig.pdf)
#
# $\;\;\;\;\;\;$ [maximal likelihood](https://github.com/ilyagerman52/bioinformatics/blob/main/homework2/trees/maxlikelihood_tree_m_orig.pdf)

# %% [markdown]
# ## Results

# %% [markdown]
# **1.** In comparison with ClustalW method, the Muscle is better, because the trees, constructed by using muscle-alignment is more close to modern evolution tree.
#
# **2.**
# We can find, that trees are really different. And sometimes most closed to each other species in first tree are really far in another.
# In other words, topology of trees is completely different.
#
# **3.** According to bootstrap values, we can see the similar sutiation: there is a huge difference.
#
# **4.** In the resulting trees human and primates rarely closer than human and rat or bovine. That's is absurd in general, but it will be normal if we says that we compare organism only by one gene.
#
# But also we can see, that plants, archaea, bacteria, fungi, animals are divided near the root in general. Thats is confirmed by modern theory of evolution.
